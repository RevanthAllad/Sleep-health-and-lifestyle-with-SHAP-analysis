# %%
#Reading data
import pandas as pd


#Fixings warnings
import warnings 
warnings.filterwarnings('ignore')


#For mathematical operations
import numpy as np


#Visualisation
import seaborn as sns 
import plotly.express as px
from termcolor import colored
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.figure_factory as ff


#Data spliting
from sklearn.model_selection import train_test_split

# %%
sleep_data=pd.read_csv("C:\\Users\\SAI REVANTH\Downloads\\ASEB 2021-25\\5TH SEMESTER\\Projects\\FoDS Project\\Sleep_health_and_lifestyle_dataset.csv")


sleep_data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv("C:\\Users\\SAI REVANTH\Downloads\\ASEB 2021-25\\5TH SEMESTER\\Projects\\FoDS Project\\Sleep_health_and_lifestyle_dataset.csv")

# Function to identify and remove outliers using IQR
def remove_outliers(df, column_name):
    # Calculate the first and third quartiles
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)

    # Calculate the IQR (Interquartile Range)
    IQR = Q3 - Q1

    # Define the upper and lower bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    # Remove outliers from the original DataFrame
    df_no_outliers = df.drop(outliers.index)

    return df_no_outliers, outliers

# Columns to consider for outlier detection (numeric columns)
numeric_columns = df.select_dtypes(include='number').columns

# Iterate through numeric columns and remove outliers
for column in numeric_columns:
    df, outliers = remove_outliers(df, column)

# Print the outliers (optional)
print("Outliers:")
print(outliers)

# Print the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)
# Out:
# Outliers:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []
#
# Cleaned DataFrame:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 1            2    Male   28             Doctor             6.2
# 2            3    Male   28             Doctor             6.2
# 7            8    Male   29             Doctor             7.8
# 8            9    Male   29             Doctor             7.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# ...

# %%
import pandas as pd

# Read the dataset
sleep_data = pd.read_csv("C:\\Users\\SAI REVANTH\\Downloads\\ASEB 2021-25\\5TH SEMESTER\\Projects\\FoDS Project\\Sleep_health_and_lifestyle_dataset.csv")

# Function to identify and remove outliers using IQR
def remove_outliers(df, column_name):
    # Calculate the first and third quartiles
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)

    # Calculate the IQR (Interquartile Range)
    IQR = Q3 - Q1

    # Define the upper and lower bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]

    # Remove outliers from the original DataFrame
    df_no_outliers = df.drop(outliers.index)

    return df_no_outliers, outliers

# Columns to consider for outlier detection (numeric columns)
numeric_columns = sleep_data.select_dtypes(include='number').columns

# Iterate through numeric columns and remove outliers
for column in numeric_columns:
    sleep_data, outliers = remove_outliers(sleep_data, column)

# Print the outliers (optional)
print("Outliers:")
print(outliers)

# Print the cleaned DataFrame
print("\nCleaned DataFrame:")
print(sleep_data)
# Out:
# Outliers:
# Empty DataFrame
# Columns: [Person ID, Gender, Age, Occupation, Sleep Duration, Quality of Sleep, Physical Activity Level, Stress Level, BMI Category, Blood Pressure, Heart Rate, Daily Steps, Sleep Disorder]
# Index: []
#
# Cleaned DataFrame:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 1            2    Male   28             Doctor             6.2
# 2            3    Male   28             Doctor             6.2
# 7            8    Male   29             Doctor             7.8
# 8            9    Male   29             Doctor             7.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# ...

# %%
shape = colored(sleep_data.shape, "magenta",None, attrs=["blink"])
print('The dimention of data is :',shape)
# Out:
# The dimention of data is : (359, 13)

# %%
sleep_data.info() # for empty and type of values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                359 non-null    int64
#  1   Gender                   359 non-null    object
#  2   Age                      359 non-null    int64
#  3   Occupation               359 non-null    object
#  4   Sleep Duration           359 non-null    float64
#  5   Quality of Sleep         359 non-null    int64
#  6   Physical Activity Level  359 non-null    int64
#  7   Stress Level             359 non-null    int64
#  8   BMI Category             359 non-null    object
#  9   Blood Pressure           359 non-null    object
#  10  Heart Rate               359 non-null    int64
#  11  Daily Steps              359 non-null    int64
#  12  Sleep Disorder           359 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 39.3+ KB

# %%
#for statistical info
sleep_data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  359.000000  359.000000      359.000000        359.000000
# mean   190.610028   42.428969        7.149582          7.376045
# std    107.055270    8.609781        0.790936          1.126415
# min      1.000000   27.000000        5.900000          5.000000
# 25%     99.500000   36.000000        6.450000          6.000000
# 50%    191.000000   43.000000        7.200000          7.000000
# 75%    284.500000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               359.000000    359.000000  359.000000    359.000000
# mean                 59.598886      5.348189   69.629526   6945.961003
# std                  20.799941      1.766760    3.231188   1513.894349
# min                  30.000000      3.000000   65.000000   4100.000000
# ...

# %%
sleep_data.describe(include='O')
# Out:
#         Gender Occupation BMI Category Blood Pressure Sleep Disorder
# count      359        359          359            359            359
# unique       2         10            3             19              3
# top     Female      Nurse       Normal         130/85           None
# freq       180         71          195             99            219

# %%
columns_name=colored(sleep_data.columns, 'magenta',None, attrs=["blink"]) #for show names of columns
print(columns_name)
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
#for colored text output ( Text ,Text colors ,Text highlights , Attributes)
number_of_values=colored(sleep_data.nunique(), "magenta",None, attrs=["blink"])
                        
print(number_of_values) #for number of values of columns
# Out:
# Person ID                  359
# Gender                       2
# Age                         30
# Occupation                  10
# Sleep Duration              26
# Quality of Sleep             5
# Physical Activity Level     13
# Stress Level                 6
# BMI Category                 3
# Blood Pressure              19
# Heart Rate                  12
# Daily Steps                 14
# Sleep Disorder               3
# dtype: int64

# %%
plt.style.use('seaborn-white')
sns.pairplot(data=sleep_data.drop('Person ID',axis=1),hue='Sleep Disorder',palette='mako')
plt.legend()
plt.show()

# %%
classes=colored(sleep_data['Sleep Disorder'].unique(), "magenta",None, attrs=["blink"])
print('The outputs from the classification are :',classes)
# Out:
# The outputs from the classification are : ['None' 'Sleep Apnea' 'Insomnia']

# %%
sleep_data['Sleep Disorder'].value_counts()
# Out:
# None           219
# Insomnia        71
# Sleep Apnea     69
# Name: Sleep Disorder, dtype: int64

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder', 
                 barmode="group",color='Sleep Disorder',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 text_auto=True)
 
    
fig.update_layout(title='<b>Distribution of persons have sleep disorder or not</b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0',
                 showlegend=True)


fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <div>                            <div id="c26cb7ca-ff78-494f-8715-1892d02876e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c26cb7ca-ff78-494f-8715-1892d02876e8")) {                    Plotly.newPlot(                        "c26cb7ca-ff78-494f-8715-1892d02876e8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None
# ...

# %%
Gender=colored(sleep_data['Gender'].unique(), "magenta",None, attrs=["blink"])
print('The values of Sex column are :',Gender)
# Out:
# The values of Sex column are : ['Male' 'Female']

# %%
sleep_data.groupby('Sleep Disorder')['Gender'].value_counts()
# Out:
# Sleep Disorder  Gender
# Insomnia        Male       36
#                 Female     35
# None            Male      137
#                 Female     82
# Sleep Apnea     Female     63
#                 Male        6
# Name: Gender, dtype: int64

# %%
sleep_data.groupby('Sleep Disorder')['Gender'].value_counts().plot.pie(autopct ='%1.1f%%',figsize=(15,7))
plt.title('The relationship between (sex) and (Sleep Disorder)')
plt.axis('equal')
plt.show()

# %%
jobs=colored(sleep_data['Occupation'].unique(), "magenta",None, attrs=["blink"])
print('The types of jobs that exist are :',jobs)
# Out:
# The types of jobs that exist are : ['Software Engineer' 'Doctor' 'Nurse' 'Engineer' 'Accountant' 'Scientist'
#  'Teacher' 'Lawyer' 'Salesperson' 'Manager']

# %%
sleep_data.groupby('Sleep Disorder')['Occupation'].value_counts()
# Out:
# Sleep Disorder  Occupation
# Insomnia        Salesperson          29
#                 Teacher              26
#                 Accountant            7
#                 Engineer              4
#                 Lawyer                2
#                 Nurse                 2
#                 Doctor                1
# None            Doctor               64
#                 Engineer             57
#                 Lawyer               42
#                 Accountant           30
#                 Nurse                 9
#                 Teacher               9
#                 Software Engineer     3
#                 Salesperson           2
#                 Scientist             2
#                 Manager               1
# Sleep Apnea     Nurse                60
#                 Teacher               4
#                 Doctor                2
#                 Engineer              1
#                 Lawyer                1
#                 Salesperson           1
# ...

# %%
sleep_data.pivot_table(index='Quality of Sleep',columns='Sleep Disorder',values='Sleep Duration',aggfunc='mean')
# Out:
# Sleep Disorder    Insomnia      None  Sleep Apnea
# Quality of Sleep
# 5                 6.500000       NaN     6.500000
# 6                 6.374194  6.117500     6.118182
# 7                 6.596875  7.540000     7.700000
# 8                 7.520000  7.399010     7.366667
# 9                 8.300000  8.365789     8.096667

# %%
fig=px.sunburst(sleep_data,path=[px.Constant('Sleep quality'),'Sleep Disorder','Quality of Sleep'],
               color='Sleep Disorder',values='Sleep Duration',
              color_discrete_sequence=['pink','#4A235A','#FFF3FD'],
              hover_data=['Gender'])

fig.update_layout(title='<b>The effect of quality of sleep on sleep </b>..',
                 title_font={'size':25})

fig.show()
# Out:
# <div>                            <div id="30827140-1cc3-4a07-a0f4-60e0e17f0183" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30827140-1cc3-4a07-a0f4-60e0e17f0183")) {                    Plotly.newPlot(                        "30827140-1cc3-4a07-a0f4-60e0e17f0183",                        [{"branchvalues":"total","customdata":[["(?)","Insomnia"],["(?)","None"],["(?)","Insomnia"],["Female","Sleep Apnea"],["Female","Insomnia"],["(?)","Sleep Apnea"],["(?)","None"],["(?)","Sleep Apnea"],["(?)","Insomnia"],["(?)","None"],["(?)","Insomnia"],["(?)","Sleep Apnea"],["(?)","None"],["(?)","Insomnia"],["(?)","Sleep Apnea"],["Male","Sleep Apnea"],["(?)","(?)"],["Female","None"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Sleep Du
# ...

# %%
fig = px.violin(sleep_data, x="Sleep Disorder",y='Physical Activity Level',
                 color='Sleep Disorder',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 violinmode='overlay')
               
    
fig.update_layout(title='<b>The effect of activities on sleep </b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0')

fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="75b6c49d-6b94-4973-99aa-921b374e76b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75b6c49d-6b94-4973-99aa-921b374e76b9")) {                    Plotly.newPlot(                        "75b6c49d-6b94-4973-99aa-921b374e76b9",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Sleep Disorder=%{x}<br>Physical Activity Level=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white"},"name":"None","offsetgroup":"None","orientation":"v","scalegroup":"True","showlegend":true,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None",
# ...

# %%
sleep_data.pivot_table(index='Gender',columns='Sleep Disorder',values='Age',aggfunc='median').plot(kind='bar',color={'#FFF3FD','#4A235A','pink'},
                                                                                                   title='Most affected ages in each type of Sleep Disorder',
                                                                                                    label='Age',alpha=.7)


plt.show()

# %%
fig=px.ecdf(sleep_data,x='Age',
            color='Sleep Disorder',
            color_discrete_sequence=['white','#4A235A','#C39BD3'])


fig.update_layout(title='<b>The effect of ages on sleep </b>..',
                 title_font={'size':25},
                 paper_bgcolor='#EBDEF0',
                 plot_bgcolor='#EBDEF0')


fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="3d02f7c2-2973-46dd-8999-ae1af81acf06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d02f7c2-2973-46dd-8999-ae1af81acf06")) {                    Plotly.newPlot(                        "3d02f7c2-2973-46dd-8999-ae1af81acf06",                        [{"hovertemplate":"Sleep Disorder=None<br>Age=%{x}<br>probability=%{y}<extra></extra>","legendgroup":"None","line":{"dash":"solid","shape":"hv"},"marker":{"color":"white","symbol":"circle"},"mode":"lines","name":"None","orientation":"v","showlegend":true,"x":[27,28,28,29,29,29,29,29,29,29,29,29,30,30,30,30,30,30,30,30,30,30,30,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,31,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,32,33,33,33,33,33,33,33,33,33,33,33,33,3
# ...

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder',y='Sleep Duration',
                 color='Sleep Disorder',color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 text_auto=True)



fig.update_layout(title='<b>The effect of Sleep Duration on Sleep Disorder</b> ..',
                  titlefont={'size': 24,'family': 'Serif'},
                  showlegend=True, 
                  paper_bgcolor='#EBDEF0',
                  plot_bgcolor='#EBDEF0')



fig.update_yaxes(showgrid=False)




fig.show()
# Out:
# <div>                            <div id="a39cf7e2-05f4-4d73-83a8-632c5dda2625" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a39cf7e2-05f4-4d73-83a8-632c5dda2625")) {                    Plotly.newPlot(                        "a39cf7e2-05f4-4d73-83a8-632c5dda2625",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Sleep Disorder=%{x}<br>sum of Sleep Duration=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None",
# ...

# %%
sleep_data.pivot_table(index='Stress Level',columns='Sleep Disorder',aggfunc={'Sleep Disorder':'count'})
# Out:
#                Sleep Disorder
# Sleep Disorder       Insomnia None Sleep Apnea
# Stress Level
# 3                           1   40          28
# 4                          24   43           3
# 5                           4   57           2
# 6                           2   43           1
# 7                          38    3           5
# 8                           2   33          30

# %%
fig=px.histogram(sleep_data,x='Sleep Disorder',
                 color='Sleep Disorder',
                 facet_col='Stress Level',
                 barmode='group',
                 color_discrete_sequence=['white','#4A235A','#C39BD3'],
                 opacity=.8)


fig.update_layout(title='<b>The effect of Stress Level on Sleep Disorder</b> ..',title_font={'size':30},
                  paper_bgcolor='#EBDEF0',
                  plot_bgcolor='#EBDEF0')



fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <div>                            <div id="18fca19e-b68c-4da0-8810-b2385abe5aae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18fca19e-b68c-4da0-8810-b2385abe5aae")) {                    Plotly.newPlot(                        "18fca19e-b68c-4da0-8810-b2385abe5aae",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sleep Disorder=%{x}<br>Stress Level=6<br>count=%{y}<extra></extra>","legendgroup":"None","marker":{"color":"white","opacity":0.8,"pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":true,"x":["None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None","None"
# ...

# %%
BMI_Category=colored(sleep_data['BMI Category'].unique(), "magenta",None, attrs=["blink"])
print('The values of BMI Category column are :',BMI_Category)
# Out:
# The values of BMI Category column are : ['Overweight' 'Normal' 'Normal Weight']

# %%
sleep_data['Blood Pressure']=sleep_data['Blood Pressure'].apply(lambda x:0 if x in ['120/80','126/83','125/80','128/84','129/84','117/76','118/76','115/75','125/82','122/80'] else 1)
# 0 = normal blood pressure
# 1 = abnormal blood pressure

# %%
sleep_data["Age"]=pd.cut(sleep_data["Age"],2)
sleep_data["Heart Rate"]=pd.cut(sleep_data["Heart Rate"],4)
sleep_data["Daily Steps"]=pd.cut(sleep_data["Daily Steps"],4)
sleep_data["Sleep Duration"]=pd.cut(sleep_data["Sleep Duration"],3)
sleep_data["Physical Activity Level"]=pd.cut(sleep_data["Physical Activity Level"],4)

# %%
from sklearn.preprocessing import LabelEncoder #for converting non-numeric data (String or Boolean) into numbers
LE=LabelEncoder()

categories=['Gender','Age','Occupation','Sleep Duration','Physical Activity Level','BMI Category','Heart Rate','Daily Steps','Sleep Disorder']
for label in categories:
    sleep_data[label]=LE.fit_transform(sleep_data[label])

# %%
sleep_data.drop(['Person ID'], axis=1, inplace=True)

# %%
correlation=sleep_data.corr()
max_6_corr=correlation.nlargest(6,"Sleep Disorder")
sns.heatmap(max_6_corr,annot=True,fmt=".2F",annot_kws={"size":8},linewidths=0.5,cmap='BuPu')
plt.title('Maximum six features affect Sleep Disorder')
plt.show()

# %%
x=sleep_data.iloc[:,:-1]
y=sleep_data.iloc[:,-1]

x_shape=colored(x.shape, "magenta",None, attrs=["blink"])
y_shape=colored(y.shape, "magenta",None, attrs=["blink"])
print('The dimensions of x is : ',x_shape)
print('The dimensions of y is : ',y_shape)
# Out:
# The dimensions of x is :  (359, 11)
# The dimensions of y is :  (359,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=32,shuffle=True)

# %%
x_train_shape=colored(x_train.shape, "magenta",None, attrs=["blink"])
x_test_shape=colored(x_test.shape, "magenta",None, attrs=["blink"])
y_train_shape=colored(y_train.shape, "magenta",None, attrs=["blink"])
y_test_shape=colored(y_test.shape, "magenta",None, attrs=["blink"])

print("x train dimensions :",x_train_shape)
print("x test dimensions: ",x_test_shape)
print("y train dimensions :",y_train_shape)
print("y test dimensions :",y_test_shape)
# Out:
# x train dimensions : (240, 11)
# x test dimensions:  (119, 11)
# y train dimensions : (240,)
# y test dimensions : (119,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the Logistic Regression model
LR = LogisticRegression().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred = LR.predict(x_train)
y_test_pred = LR.predict(x_test)

# Calculate and print the training and testing scores
LR_training_score = colored(round(LR.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
LR_testing_score = colored(round(LR.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

print(f"LR training score: {LR_training_score}")
print("LR testing score:", LR_testing_score)

# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# LR training score: 92.08
# LR testing score: 90.76
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.93      0.92        71
#            2       0.83      0.89      0.86        27
#
#     accuracy                           0.91       119
#    macro avg       0.91      0.89      0.90       119
# weighted avg       0.91      0.91      0.91       119

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the Logistic Regression model
LR = LogisticRegression().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred = LR.predict(x_train)
y_test_pred = LR.predict(x_test)

# Calculate and print the training and testing scores
LR_training_score = colored(round(LR.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
LR_testing_score = colored(round(LR.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train = accuracy_score(y_train, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

# Print accuracy
accuracy_train_colored = colored(round(accuracy_train * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored = colored(round(accuracy_test * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored}%")


# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy on training set: 92.08%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.93      0.92        71
#            2       0.83      0.89      0.86        27
#
#     accuracy                           0.91       119
#    macro avg       0.91      0.89      0.90       119
# weighted avg       0.91      0.91      0.91       119

# %%
LR_y_pred=LR.predict(x_test)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the XGBoost model
xgb = XGBClassifier().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_xgb = xgb.predict(x_train)
y_test_pred_xgb = xgb.predict(x_test)

# Calculate and print the training and testing scores
xgb_training_score = colored(round(xgb.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
xgb_testing_score = colored(round(xgb.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_xgb = accuracy_score(y_train, y_train_pred_xgb)
accuracy_test_xgb = accuracy_score(y_test, y_test_pred_xgb)

# Print accuracy
accuracy_train_colored_xgb = colored(round(accuracy_train_xgb * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_xgb = colored(round(accuracy_test_xgb * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored_xgb}%")

# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_xgb))
# Out:
# Accuracy on training set: 92.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.97      0.95        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.93       119
#    macro avg       0.95      0.91      0.92       119
# weighted avg       0.93      0.93      0.93       119

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the Support Vector Classifier (SVC) model
svc = SVC().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_svc = svc.predict(x_train)
y_test_pred_svc = svc.predict(x_test)

# Calculate and print the training and testing scores
svc_training_score = colored(round(svc.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
svc_testing_score = colored(round(svc.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_svc = accuracy_score(y_train, y_train_pred_svc)
accuracy_test_svc = accuracy_score(y_test, y_test_pred_svc)

# Print accuracy
accuracy_train_colored_svc = colored(round(accuracy_train_svc * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_svc = colored(round(accuracy_test_svc * 100, 2), "magenta", None, attrs=["blink"])

print(f"Accuracy on training set: {accuracy_train_colored_svc}%")


# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_svc))
# Out:
# Accuracy on training set: 87.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85        21
#            1       0.92      0.96      0.94        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.92       119
#    macro avg       0.91      0.89      0.90       119
# weighted avg       0.92      0.92      0.92       119

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the Random Forest model
rf = RandomForestClassifier().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_rf = rf.predict(x_train)
y_test_pred_rf = rf.predict(x_test)

# Calculate and print the training and testing scores
rf_training_score = colored(round(rf.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
rf_testing_score = colored(round(rf.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_rf = accuracy_score(y_train, y_train_pred_rf)
accuracy_test_rf = accuracy_score(y_test, y_test_pred_rf)

# Print accuracy
accuracy_train_colored_rf = colored(round(accuracy_train_rf * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_rf = colored(round(accuracy_test_rf * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored_rf}%")

# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_rf))
# Out:
# Accuracy on training set: 92.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.97      0.95        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.93       119
#    macro avg       0.95      0.91      0.92       119
# weighted avg       0.93      0.93      0.93       119

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the k-NN model
knn = KNeighborsClassifier().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_knn = knn.predict(x_train)
y_test_pred_knn = knn.predict(x_test)

# Calculate and print the training and testing scores
knn_training_score = colored(round(knn.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
knn_testing_score = colored(round(knn.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_knn = accuracy_score(y_train, y_train_pred_knn)
accuracy_test_knn = accuracy_score(y_test, y_test_pred_knn)

# Print accuracy
accuracy_train_colored_knn = colored(round(accuracy_train_knn * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_knn = colored(round(accuracy_test_knn * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored_knn}%")

# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_knn))
# Out:
# Accuracy on training set: 89.58%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        21
#            1       0.92      0.96      0.94        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.92       119
#    macro avg       0.93      0.90      0.91       119
# weighted avg       0.92      0.92      0.92       119

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create a base classifier (e.g., Decision Tree)
base_classifier = DecisionTreeClassifier()

# Create and fit the Bagging Classifier
bagging_classifier = BaggingClassifier(base_classifier, n_estimators=10, random_state=42).fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_bagging = bagging_classifier.predict(x_train)
y_test_pred_bagging = bagging_classifier.predict(x_test)

# Calculate and print the training and testing scores
bagging_training_score = colored(round(bagging_classifier.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
bagging_testing_score = colored(round(bagging_classifier.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_bagging = accuracy_score(y_train, y_train_pred_bagging)
accuracy_test_bagging = accuracy_score(y_test, y_test_pred_bagging)

# Print accuracy
accuracy_train_colored_bagging = colored(round(accuracy_train_bagging * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_bagging = colored(round(accuracy_test_bagging * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored_bagging}%")


# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_bagging))
# Out:
# Accuracy on training set: 92.5%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.96      0.94        71
#            2       0.89      0.89      0.89        27
#
#     accuracy                           0.92       119
#    macro avg       0.94      0.90      0.92       119
# weighted avg       0.93      0.92      0.92       119

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Create and fit the Naive Bayes (Gaussian) model
naive_bayes = GaussianNB().fit(x_train, y_train)

# Make predictions on the training and testing set
y_train_pred_nb = naive_bayes.predict(x_train)
y_test_pred_nb = naive_bayes.predict(x_test)

# Calculate and print the training and testing scores
nb_training_score = colored(round(naive_bayes.score(x_train, y_train) * 100, 2), "magenta", None, attrs=["blink"])
nb_testing_score = colored(round(naive_bayes.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_nb = accuracy_score(y_train, y_train_pred_nb)
accuracy_test_nb = accuracy_score(y_test, y_test_pred_nb)

# Print accuracy
accuracy_train_colored_nb = colored(round(accuracy_train_nb * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_nb = colored(round(accuracy_test_nb * 100, 2), "magenta", None, attrs=["blink"])


print(f"Accuracy on training set: {accuracy_train_colored_nb}%")


# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred_nb))
# Out:
# Accuracy on training set: 91.25%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        21
#            1       0.92      0.93      0.92        71
#            2       0.86      0.89      0.87        27
#
#     accuracy                           0.91       119
#    macro avg       0.91      0.89      0.90       119
# weighted avg       0.91      0.91      0.91       119

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming x_train and y_train are your training features and labels respectively
# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Check the class distribution after applying SMOTE
print("Class distribution after SMOTE:", Counter(y_train_balanced))

import matplotlib.pyplot as plt
from collections import Counter

# Assuming x_train and y_train are your original training features and labels respectively

# Calculate class distribution before SMOTE
original_class_distribution = Counter(y_train)

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Calculate class distribution after SMOTE
balanced_class_distribution = Counter(y_train_balanced)

# Plot the bar plot
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot before SMOTE
ax[0].bar(original_class_distribution.keys(), original_class_distribution.values(), color='blue')
ax[0].set_title('Class Distribution Before SMOTE')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Count')

# Bar plot after SMOTE
ax[1].bar(balanced_class_distribution.keys(), balanced_class_distribution.values(), color='green')
ax[1].set_title('Class Distribution After SMOTE')
ax[1].set_xlabel('Class')
ax[1].set_ylabel('Count')

plt.show()
# Out:
# Class distribution after SMOTE: Counter({0: 148, 1: 148, 2: 148})

# %%
# Import Libraries
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import numpy as np
import seaborn as sns 
import plotly.express as px
from termcolor import colored
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.figure_factory as ff
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from collections import Counter

# Load Data
sleep_data = pd.read_csv("C:\\Users\\SAI REVANTH\Downloads\\ASEB 2021-25\\5TH SEMESTER\\Projects\\FoDS Project\\Sleep_health_and_lifestyle_dataset.csv")

# %%
# Create and fit the Logistic Regression model
LR = LogisticRegression().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred = LR.predict(x_train_balanced)
y_test_pred = LR.predict(x_test)

# Calculate and print the training and testing scores
LR_training_score = colored(round(LR.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
LR_testing_score = colored(round(LR.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

print(f"LR training score: {LR_training_score}")
print("LR testing score:", LR_testing_score)

# Calculate and print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# LR training score: 90.09
# LR testing score: 89.92
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93        21
#            1       0.94      0.90      0.92        71
#            2       0.77      0.89      0.83        27
#
#     accuracy                           0.90       119
#    macro avg       0.89      0.90      0.89       119
# weighted avg       0.90      0.90      0.90       119

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the Logistic Regression model
LR = LogisticRegression().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred = LR.predict(x_train_balanced)
y_test_pred = LR.predict(x_test)

# Calculate and print the training and testing scores
LR_training_score = colored(round(LR.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
LR_testing_score = colored(round(LR.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train = accuracy_score(y_train_balanced, y_train_pred)
accuracy_test = accuracy_score(y_test, y_test_pred)

# Print accuracy
accuracy_train_colored = colored(round(accuracy_train * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored = colored(round(accuracy_test * 100, 2), "magenta", None, attrs=["blink"])

print(f"Logistic Regression - Accuracy on training set: {accuracy_train_colored}%")
print("Logistic Regression - Accuracy on testing set:", accuracy_test_colored)

# Calculate and print the classification report
print("\nLogistic Regression - Classification Report:")
print(classification_report(y_test, y_test_pred))
# Out:
# Logistic Regression - Accuracy on training set: 90.09%
# Logistic Regression - Accuracy on testing set: 89.92
#
# Logistic Regression - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93        21
#            1       0.94      0.90      0.92        71
#            2       0.77      0.89      0.83        27
#
#     accuracy                           0.90       119
#    macro avg       0.89      0.90      0.89       119
# weighted avg       0.90      0.90      0.90       119

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the XGBoost model
xgb = XGBClassifier().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_xgb = xgb.predict(x_train_balanced)
y_test_pred_xgb = xgb.predict(x_test)

# Calculate and print the training and testing scores
xgb_training_score = colored(round(xgb.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
xgb_testing_score = colored(round(xgb.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_xgb = accuracy_score(y_train_balanced, y_train_pred_xgb)
accuracy_test_xgb = accuracy_score(y_test, y_test_pred_xgb)

# Print accuracy
accuracy_train_colored_xgb = colored(round(accuracy_train_xgb * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_xgb = colored(round(accuracy_test_xgb * 100, 2), "magenta", None, attrs=["blink"])

print(f"XGBoost - Accuracy on training set: {accuracy_train_colored_xgb}%")
print("XGBoost - Accuracy on testing set:", accuracy_test_colored_xgb)

# Calculate and print the classification report
print("\nXGBoost - Classification Report:")
print(classification_report(y_test, y_test_pred_xgb))
# Out:
# XGBoost - Accuracy on training set: 94.82%
# XGBoost - Accuracy on testing set: 93.28
#
# XGBoost - Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.97      0.95        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.93       119
#    macro avg       0.95      0.91      0.92       119
# weighted avg       0.93      0.93      0.93       119

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the Support Vector Classifier (SVC) model
svc = SVC().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_svc = svc.predict(x_train_balanced)
y_test_pred_svc = svc.predict(x_test)

# Calculate and print the training and testing scores
svc_training_score = colored(round(svc.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
svc_testing_score = colored(round(svc.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_svc = accuracy_score(y_train_balanced, y_train_pred_svc)
accuracy_test_svc = accuracy_score(y_test, y_test_pred_svc)

# Print accuracy
accuracy_train_colored_svc = colored(round(accuracy_train_svc * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_svc = colored(round(accuracy_test_svc * 100, 2), "magenta", None, attrs=["blink"])

print(f"SVM - Accuracy on training set: {accuracy_train_colored_svc}%")
print("SVM - Accuracy on testing set:", accuracy_test_colored_svc)

# Calculate and print the classification report
print("\nSVM - Classification Report:")
print(classification_report(y_test, y_test_pred_svc))
# Out:
# SVM - Accuracy on training set: 88.06%
# SVM - Accuracy on testing set: 90.76
#
# SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86        21
#            1       0.94      0.92      0.93        71
#            2       0.89      0.89      0.89        27
#
#     accuracy                           0.91       119
#    macro avg       0.89      0.90      0.89       119
# weighted avg       0.91      0.91      0.91       119

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the Random Forest model
rf = RandomForestClassifier().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_rf = rf.predict(x_train_balanced)
y_test_pred_rf = rf.predict(x_test)

# Calculate and print the training and testing scores
rf_training_score = colored(round(rf.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
rf_testing_score = colored(round(rf.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_rf = accuracy_score(y_train_balanced, y_train_pred_rf)
accuracy_test_rf = accuracy_score(y_test, y_test_pred_rf)

# Print accuracy
accuracy_train_colored_rf = colored(round(accuracy_train_rf * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_rf = colored(round(accuracy_test_rf * 100, 2), "magenta", None, attrs=["blink"])

print(f"Random Forest - Accuracy on training set: {accuracy_train_colored_rf}%")
print("Random Forest - Accuracy on testing set:", accuracy_test_colored_rf)

# Calculate and print the classification report
print("\nRandom Forest - Classification Report:")
print(classification_report(y_test, y_test_pred_rf))
# Out:
# Random Forest - Accuracy on training set: 94.82%
# Random Forest - Accuracy on testing set: 93.28
#
# Random Forest - Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92        21
#            1       0.92      0.97      0.95        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.93       119
#    macro avg       0.95      0.91      0.92       119
# weighted avg       0.93      0.93      0.93       119

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the k-NN model
knn = KNeighborsClassifier().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_knn = knn.predict(x_train_balanced)
y_test_pred_knn = knn.predict(x_test)

# Calculate and print the training and testing scores
knn_training_score = colored(round(knn.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
knn_testing_score = colored(round(knn.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_knn = accuracy_score(y_train_balanced, y_train_pred_knn)
accuracy_test_knn = accuracy_score(y_test, y_test_pred_knn)

# Print accuracy
accuracy_train_colored_knn = colored(round(accuracy_train_knn * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_knn = colored(round(accuracy_test_knn * 100, 2), "magenta", None, attrs=["blink"])

print(f"K-NN - Accuracy on training set: {accuracy_train_colored_knn}%")
print("K-NN - Accuracy on testing set:", accuracy_test_colored_knn)

# Calculate and print the classification report
print("\nK-NN - Classification Report:")
print(classification_report(y_test, y_test_pred_knn))
# Out:
# K-NN - Accuracy on training set: 91.67%
# K-NN - Accuracy on testing set: 92.44
#
# K-NN - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        21
#            1       0.94      0.94      0.94        71
#            2       0.86      0.93      0.89        27
#
#     accuracy                           0.92       119
#    macro avg       0.92      0.91      0.91       119
# weighted avg       0.93      0.92      0.92       119

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create a base classifier (e.g., Decision Tree)
base_classifier = DecisionTreeClassifier()

# Create and fit the Bagging Classifier
bagging_classifier = BaggingClassifier(base_classifier, n_estimators=10, random_state=42).fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_bagging = bagging_classifier.predict(x_train_balanced)
y_test_pred_bagging = bagging_classifier.predict(x_test)

# Calculate and print the training and testing scores
bagging_training_score = colored(round(bagging_classifier.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
bagging_testing_score = colored(round(bagging_classifier.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_bagging = accuracy_score(y_train_balanced, y_train_pred_bagging)
accuracy_test_bagging = accuracy_score(y_test, y_test_pred_bagging)

# Print accuracy
accuracy_train_colored_bagging = colored(round(accuracy_train_bagging * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_bagging = colored(round(accuracy_test_bagging * 100, 2), "magenta", None, attrs=["blink"])

print(f"Bagging Classifier - Accuracy on training set: {accuracy_train_colored_bagging}%")
print("Bagging Classifier - Accuracy on testing set:", accuracy_test_colored_bagging)

# Calculate and print the classification report
print("\nBagging Classifier - Classification Report:")
print(classification_report(y_test, y_test_pred_bagging))
# Out:
# Bagging Classifier - Accuracy on training set: 94.59%
# Bagging Classifier - Accuracy on testing set: 92.44
#
# Bagging Classifier - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        21
#            1       0.92      0.96      0.94        71
#            2       0.92      0.89      0.91        27
#
#     accuracy                           0.92       119
#    macro avg       0.93      0.90      0.91       119
# weighted avg       0.92      0.92      0.92       119

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored  # Assuming you are using termcolor for colored output
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Create and fit the Naive Bayes (Gaussian) model
naive_bayes = GaussianNB().fit(x_train_balanced, y_train_balanced)

# Make predictions on the training and testing set
y_train_pred_nb = naive_bayes.predict(x_train_balanced)
y_test_pred_nb = naive_bayes.predict(x_test)

# Calculate and print the training and testing scores
nb_training_score = colored(round(naive_bayes.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
nb_testing_score = colored(round(naive_bayes.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_nb = accuracy_score(y_train_balanced, y_train_pred_nb)
accuracy_test_nb = accuracy_score(y_test, y_test_pred_nb)

# Print accuracy
accuracy_train_colored_nb = colored(round(accuracy_train_nb * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_nb = colored(round(accuracy_test_nb * 100, 2), "magenta", None, attrs=["blink"])

print(f"Naive Bayes - Accuracy on training set: {accuracy_train_colored_nb}%")
print("Naive Bayes - Accuracy on testing set:", accuracy_test_colored_nb)

# Calculate and print the classification report
print("\nNaive Bayes - Classification Report:")
print(classification_report(y_test, y_test_pred_nb))
# Out:
# Naive Bayes - Accuracy on training set: 87.61%
# Naive Bayes - Accuracy on testing set: 90.76
#
# Naive Bayes - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        21
#            1       0.94      0.92      0.93        71
#            2       0.86      0.89      0.87        27
#
#     accuracy                           0.91       119
#    macro avg       0.89      0.90      0.90       119
# weighted avg       0.91      0.91      0.91       119

# %%
import shap
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter
import matplotlib.pyplot as plt

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Check the class distribution after applying SMOTE
print("Class distribution after SMOTE:", Counter(y_train_balanced))

# Create and fit the Random Forest model on balanced data
rf = RandomForestClassifier().fit(x_train_balanced, y_train_balanced)

# Fits the explainer
explainer = shap.Explainer(rf.predict, x_test)
# Calculates the SHAP values - It takes some time
shap_values = explainer(x_test)

# Make predictions on the training and testing set
y_train_pred_rf = rf.predict(x_train_balanced)
y_test_pred_rf = rf.predict(x_test)

# Calculate and print the training and testing scores
rf_training_score = colored(round(rf.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
rf_testing_score = colored(round(rf.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_rf = accuracy_score(y_train_balanced, y_train_pred_rf)
accuracy_test_rf = accuracy_score(y_test, y_test_pred_rf)

# Print accuracy
accuracy_train_colored_rf = colored(round(accuracy_train_rf * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_rf = colored(round(accuracy_test_rf * 100, 2), "magenta", None, attrs=["blink"])

# Print SHAP values summary
shap.summary_plot(shap_values, x_test, plot_type="bar", class_names=rf.classes_)

# Plot the bar plot for class distribution
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot before SMOTE
ax[0].bar(original_class_distribution.keys(), original_class_distribution.values(), color='blue')
ax[0].set_title('Class Distribution Before SMOTE')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Count')

# Bar plot after SMOTE
ax[1].bar(balanced_class_distribution.keys(), balanced_class_distribution.values(), color='green')
ax[1].set_title('Class Distribution After SMOTE')
ax[1].set_xlabel('Class')
ax[1].set_ylabel('Count')

plt.show()
# Out:
# Class distribution after SMOTE: Counter({0: 148, 1: 148, 2: 148})
# Permutation explainer: 120it [01:12,  1.53it/s]

# %%
import shap
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from termcolor import colored
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter
import matplotlib.pyplot as plt

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Apply SMOTE to balance classes
smote = SMOTE(random_state=42)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

# Check the class distribution after applying SMOTE
print("Class distribution after SMOTE:", Counter(y_train_balanced))

# Create and fit the Random Forest model on balanced data
rf = RandomForestClassifier().fit(x_train_balanced, y_train_balanced)

# Fits the explainer
explainer = shap.Explainer(rf.predict, x_test)
# Calculates the SHAP values - It takes some time
shap_values = explainer(x_test)

# Make predictions on the training and testing set
y_train_pred_rf = rf.predict(x_train_balanced)
y_test_pred_rf = rf.predict(x_test)

# Calculate and print the training and testing scores
rf_training_score = colored(round(rf.score(x_train_balanced, y_train_balanced) * 100, 2), "magenta", None, attrs=["blink"])
rf_testing_score = colored(round(rf.score(x_test, y_test) * 100, 2), "magenta", None, attrs=["blink"])

# Calculate accuracy
accuracy_train_rf = accuracy_score(y_train_balanced, y_train_pred_rf)
accuracy_test_rf = accuracy_score(y_test, y_test_pred_rf)

# Print accuracy
accuracy_train_colored_rf = colored(round(accuracy_train_rf * 100, 2), "magenta", None, attrs=["blink"])
accuracy_test_colored_rf = colored(round(accuracy_test_rf * 100, 2), "magenta", None, attrs=["blink"])

# Print SHAP values summary
shap.summary_plot(shap_values, x_test, plot_type="bar", class_names=rf.classes_)

# Plot the SHAP bar plot
shap.plots.bar(shap_values)

# Plot the bar plot for class distribution
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot before SMOTE
ax[0].bar(original_class_distribution.keys(), original_class_distribution.values(), color='blue')
ax[0].set_title('Class Distribution Before SMOTE')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Count')

# Bar plot after SMOTE
ax[1].bar(balanced_class_distribution.keys(), balanced_class_distribution.values(), color='green')
ax[1].set_title('Class Distribution After SMOTE')
ax[1].set_xlabel('Class')
ax[1].set_ylabel('Count')

plt.show()
# Out:
# Class distribution after SMOTE: Counter({0: 148, 1: 148, 2: 148})
# Permutation explainer: 120it [01:05,  1.55it/s]

# %%
shap.summary_plot(shap_values)

# %%
shap.summary_plot(shap_values, plot_type='violin')

# %%
shap.plots.bar(shap_values[1])

# %%
shap.plots.bar(shap_values[0])

# %%
shap.plots.waterfall(shap_values[6])

# %%
shap.plots.waterfall(shap_values[0])

# %%
import shap
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Initialize the SHAP JavaScript library
shap.initjs()

# Create and fit the Random Forest model
classes = ['None', 'Sleep Apnea', 'Insomnia']
rf = RandomForestClassifier().fit(x_train, y_train)

# Fits the explainer
explainer = shap.Explainer(rf)
shap_values = explainer.shap_values(x_test)

# Plot the SHAP values decision plot for the first instance
shap.decision_plot(
    base_value=explainer.expected_value[2],
    shap_values=shap_values[2],
    features=x_test.iloc[0, :],
    feature_names=list(x_test.columns)  # Convert to a list
)

# Display the plot
plt.show()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
import shap
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Assuming you have already defined x_train, y_train, x_test, and y_test

# Initialize the SHAP JavaScript library
shap.initjs()

# Create and fit the Random Forest model
classes = ['None', 'Sleep Apnea', 'Insomnia']
rf = RandomForestClassifier().fit(x_train, y_train)

# Fits the explainer
explainer = shap.Explainer(rf)
shap_values = explainer.shap_values(x_test)

# Plot the SHAP values decision plot for the first instance
shap.decision_plot(
    base_value=explainer.expected_value[0],
    shap_values=shap_values[0],
    features=x_test.iloc[0, :],
    feature_names=list(x_test.columns)  # Convert to a list
)

# Display the plot
plt.show()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...
